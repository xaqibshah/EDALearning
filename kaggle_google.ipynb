# %% [markdown]
# # Google Playstore Data

# %% [markdown]
# ## Complete EDA analysis for Beginner to Advance

# %% [markdown]
# Content Table:
# 1. Install & import  libraries
# 2. Import data set of Google Playstore
# 3. create ydata Profile Report for overview

# %% [markdown]
# 1. Download the data
# 2. Extract data from zip file
# 3. read the data into python pandas
# 4. check each column
# 5. define each column in MD style

# %% [markdown]
# **Context**\
# While many public datasets (on Kaggle and the like) provide Apple App Store data, there are not many counterpart datasets available for Google Play Store apps anywhere on the web. On digging deeper, I found out that iTunes App Store page deploys a nicely indexed appendix-like structure to allow for simple and easy web scraping. On the other hand, Google Play Store uses sophisticated modern-day techniques (like dynamic page load) using JQuery making scraping more challenging.
#
# **Content**\
# Each app (row) has values for catergory, rating, size, and more.
#
# **Acknowledgements**\
# This information is scraped from the Google Play Store. This app information would not be available without it.
#
# **Inspiration**\
# The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market!

# %% [markdown]
# ### 1. Import Libraries

# %%
#import libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#remove below coment if you want auto EDA
# import ydata_profiling as yd

# %% [markdown]
# ### 2. Import Dataset of Google Playstore| Exploration | Clearning

# %% [markdown]
# - let's load the dataset

# %%
# data import
df = pd.read_csv("data/googlePlaystore/googleplaystore.csv")

# %% [markdown]
# - lets load first five columns

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# ...

# %% [markdown]
# ### set options to be maximum for rows and columns

# %%
#set options to be maximum for rows and columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# hide all warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 3. Create EDA through ydata profiling for overview

# %%
# run autometic eda using ydata-profiling library
#remove below coment if you want auto EDA
# profile = yd.ProfileReport(df)
# profile.to_file('output/googlePlaystoreEDA.htm')

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.shape
# Out:
# (10841, 13)

# %%
print(f"The Number of Rows are {df.shape[0]}, and columns are {df.shape[1]}")
# Out:
# The Number of Rows are 10841, and columns are 13

# %%
#check the data information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             Rating       Reviews
# count  9367.000000  1.084100e+04
# mean      4.191513  4.441119e+05
# std       0.515735  2.927629e+06
# min       1.000000  0.000000e+00
# 25%       4.000000  3.800000e+01
# 50%       4.300000  2.094000e+03
# 75%       4.500000  5.476800e+04
# max       5.000000  7.815831e+07

# %%
# to check head data
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# ...

# %%
# for selecting random sample of data
df.sample(10)
# Out:
#                                                      App            Category  \
# 4328                                Messenger L SMS, MMS     PERSONALIZATION
# 10050                             Advanced EX for NISSAN               TOOLS
# 3752                                            ARY NEWS  NEWS_AND_MAGAZINES
# 6416   Lust in Terror Manor - The Truth Unveiled | Otome                GAME
# 7520                    Postings (Craigslist Search App)            SHOPPING
# 1200                            Chef - Recipes & Cooking      FOOD_AND_DRINK
# 3055   theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 3260   File Manager -- Take Command of Your Files Easily               TOOLS
# 5559                                Arcraft - AR Sandbox                GAME
# 2974                         FotMob - Live Soccer Scores              SPORTS
#
#        Rating  Reviews                Size     Installs  Type   Price  \
# ...

# %%
df.describe()
# Out:
#             Rating       Reviews
# count  9367.000000  1.084100e+04
# mean      4.191513  4.441119e+05
# std       0.515735  2.927629e+06
# min       1.000000  0.000000e+00
# 25%       4.000000  3.800000e+01
# 50%       4.300000  2.094000e+03
# 75%       4.500000  5.476800e+04
# max       5.000000  7.815831e+07

# %% [markdown]
# ### Write down all the numeric variables and convert them into numeric
# 1. install
# 2. price
# 3. size

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             908
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Name: count, dtype: int64

# %%
#remove + sign , ',' from Installs  and convert into integer 
# df['Installs'] = df['Installs'].apply(lambda x: x.replace('+',''))
# df['Installs'] = df['Installs'].apply(lambda x: x.replace(',',''))
df['Installs'] = df['Installs'].apply(lambda x: int(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 4
#       1 #remove + sign , ',' from Installs  and convert into integer
#       2 # df['Installs'] = df['Installs'].apply(lambda x: x.replace('+',''))
#       3 # df['Installs'] = df['Installs'].apply(lambda x: x.replace(',',''))
# ----> 4 df['Installs'] = df['Installs'].apply(lambda x: int(x))
#
# File c:\Users\xaqibshah\.conda\envs\python_eda\Lib\site-packages\pandas\core\series.py:4760, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4625 def apply(
#    4626     self,
#    4627     func: AggFuncType,
#    (...)
#    4632     **kwargs,
#    4633 ) -> DataFrame | Series:
#    4634     """
#    4635     Invoke function on values of Series.
#    4636
#    (...)
#    4751     dtype: float64
#    4752     """
#    4753     return SeriesApply(
#    4754         self,
#    4755         func,
# ...

# %%
df.describe()
# Out:
#             Rating       Reviews      Installs         Price
# count  9367.000000  1.084100e+04  1.084100e+04  10841.000000
# mean      4.191513  4.441119e+05  1.546291e+07      1.027273
# std       0.515735  2.927629e+06  8.502557e+07     15.948971
# min       1.000000  0.000000e+00  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03  1.000000e+05      0.000000
# 75%       4.500000  5.476800e+04  5.000000e+06      0.000000
# max       5.000000  7.815831e+07  1.000000e+09    400.000000

# %% [markdown]
# ### Bening in install columns with its installs range

# %%
# lets have look on unique values
# df.Size.unique()
# df['Size'].nunique()
df['Size'].value_counts()
# Out:
# Size
# Varies with device    1694
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 430k                     1
# 429k                     1
# 200k                     1
# 460k                     1
# 619k                     1
# Name: count, Length: 461, dtype: int64

# %% [markdown]
# verify the number of values and 3 different kinds of values

# %%
#find the values having m in size column
# find the values having n in name column
df['Size'].loc[df['Size'].str.contains('M')].value_counts().sum()
# Out:
# 8831

# %%
df['Size'].loc[df['Size'].str.contains('k')].value_counts().sum()
# Out:
# 316

# %%
df['Size'].loc[df['Size'].str.contains('Varies with device')].value_counts()
# Out:
# Size
# Varies with device    1694
# Name: count, dtype: int64

# %%
len(df)
# Out:
# 10841

# %%
# convert size into MBs
def convert_size(size):
    if isinstance(size, str):
        if 'k' in size:
            return float(size.replace('k', ''))*1024
        elif 'M' in size:
            return float(size.replace('M', ''))*1024*1024
        elif 'Varies with device' in size:
            return np.nan
    return size

# %%
df.Size
# Out:
# 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
# 5                      5.6M
# 6                       19M
# 7                       29M
# 8                       33M
# 9                      3.1M
# 10                      28M
# 11                      12M
# 12                      20M
# 13                      21M
# 14                      37M
# 15                     2.7M
# 16                     5.5M
# 17                      17M
# 18                      39M
# 19                      31M
# 20                      14M
# 21                      12M
# 22                     4.2M
# 23                     7.0M
# 24                      23M
# 25                     6.0M
# 26                      25M
# 27                     6.1M
# 28                     4.6M
# 29                     4.2M
# 30                     9.2M
# 31                     5.2M
# 32                      11M
# ...

# %%
df['Size']=df['Size'].apply(convert_size)

# %%
# rename the culumn
df.rename(columns={'Size':'Size_bytes'}, inplace=True)

# %%
df['Size_Mb'] = df['Size_bytes'].apply(lambda x:  x/(1024*1024))

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size_bytes     Installs  Type Price Content Rating  \
# 0      159  19922944.0      10,000+  Free     0       Everyone
# 1      967  14680064.0     500,000+  Free     0       Everyone
# 2    87510   9122611.2   5,000,000+  Free     0       Everyone
# 3   215644  26214400.0  50,000,000+  Free     0           Teen
# 4      967   2936012.8     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# ...

# %%
#convert price column into numeric
df['Price'] = df['Price'].apply(lambda x: x.replace('$',''))
df['Price'] = df['Price'].apply(lambda x: float(x))

# %%
df.describe()
# Out:
#             Rating       Reviews         Price
# count  9367.000000  1.084100e+04  10841.000000
# mean      4.191513  4.441119e+05      1.027273
# std       0.515735  2.927629e+06     15.948971
# min       1.000000  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01      0.000000
# 50%       4.300000  2.094000e+03      0.000000
# 75%       4.500000  5.476800e+04      0.000000
# max       5.000000  7.815831e+07    400.000000

# %%
df.Installs
# Out:
# 0               10,000+
# 1              500,000+
# 2            5,000,000+
# 3           50,000,000+
# 4              100,000+
# 5               50,000+
# 6               50,000+
# 7            1,000,000+
# 8            1,000,000+
# 9               10,000+
# 10           1,000,000+
# 11           1,000,000+
# 12          10,000,000+
# 13             100,000+
# 14             100,000+
# 15               5,000+
# 16             500,000+
# 17              10,000+
# 18           5,000,000+
# 19          10,000,000+
# 20             100,000+
# 21             100,000+
# 22             500,000+
# 23             100,000+
# 24              50,000+
# 25              10,000+
# 26             500,000+
# 27             100,000+
# 28              10,000+
# 29             100,000+
# 30             100,000+
# 31              50,000+
# 32             100,000+
# 33             100,000+
# 34              10,000+
# 35             100,000+
# 36             500,000+
# 37           5,000,000+
# ...

# %%
#remove + sign from Installs columns and convert into float.
# df['Installs'] = df['Installs'].str.replace('+', '').astype(float)
df['Installs'] = df['Installs'].apply(lambda x: x.replace('+',''))
df['Installs'] = df['Installs'].apply(lambda x: x.replace(',',''))
df['Installs'] = df['Installs'].apply(lambda x: float(x))

# %%
df.Installs
# Out:
# 0               10,000
# 1              500,000
# 2            5,000,000
# 3           50,000,000
# 4              100,000
# 5               50,000
# 6               50,000
# 7            1,000,000
# 8            1,000,000
# 9               10,000
# 10           1,000,000
# 11           1,000,000
# 12          10,000,000
# 13             100,000
# 14             100,000
# 15               5,000
# 16             500,000
# 17              10,000
# 18           5,000,000
# 19          10,000,000
# 20             100,000
# 21             100,000
# 22             500,000
# 23             100,000
# 24              50,000
# 25              10,000
# 26             500,000
# 27             100,000
# 28              10,000
# 29             100,000
# 30             100,000
# 31              50,000
# 32             100,000
# 33             100,000
# 34              10,000
# 35             100,000
# 36             500,000
# 37           5,000,000
# 38              10,000
# 39             500,000
# ...

# %%
df.describe()
# Out:
#             Rating       Reviews    Size_bytes      Installs      Size_Mb
# count  9367.000000  1.084100e+04  9.147000e+03  1.084100e+04  9147.000000
# mean      4.191513  4.441119e+05  2.255700e+07  1.546291e+07    21.512029
# std       0.515735  2.927629e+06  2.368560e+07  8.502557e+07    22.588347
# min       1.000000  0.000000e+00  8.704000e+03  0.000000e+00     0.008301
# 25%       4.000000  3.800000e+01  5.138022e+06  1.000000e+03     4.900000
# 50%       4.300000  2.094000e+03  1.363149e+07  1.000000e+05    13.000000
# 75%       4.500000  5.476800e+04  3.145728e+07  5.000000e+06    30.000000
# max       5.000000  7.815831e+07  1.048576e+08  1.000000e+09   100.000000

# %%
df['Price'].value_counts()
# Out:
# Price
# 0           10041
# $0.99         148
# $2.99         129
# $1.99          73
# $4.99          72
# $3.99          63
# $1.49          46
# $5.99          30
# $2.49          26
# $9.99          21
# $6.99          13
# $399.99        12
# $14.99         11
# $4.49           9
# $29.99          7
# $24.99          7
# $3.49           7
# $7.99           7
# $5.49           6
# $19.99          6
# $11.99          5
# $6.49           5
# $12.99          5
# $8.99           5
# $10.00          3
# $16.99          3
# $1.00           3
# $2.00           3
# $13.99          2
# $8.49           2
# $17.99          2
# $1.70           2
# $3.95           2
# $79.99          2
# $7.49           2
# $9.00           2
# $10.99          2
# $39.99          2
# $33.99          2
# $1.96           1
# $19.40          1
# $4.80           1
# $3.28           1
# $4.59           1
# $15.46          1
# $3.04           1
# $4.29           1
# $2.60           1
# $2.59           1
# ...

# %%
#remove $ sign from Price Column and convert into integer
# df['Price'] = df['Price'].apply(lambda x: x.replace('$',''))
df['Price'] = df['Price'].apply(lambda x: x.replace('$',''))
# df['Price'] = df['Price'].apply(lambda x: int(x))

# %%
df['Price'].loc[df['Price'].str.contains('\$')].value_counts().sum()
# Out:
# 0

# %%
df['Price'].loc[(df['Price'].str.contains('0'))& (~df['Price'].str.contains('\$'))].value_counts().sum()
# Out:
# 10224

# %%
df.Price.value_counts()
# Out:
# Price
# 0          10041
# 0.99         148
# 2.99         129
# 1.99          73
# 4.99          72
# 3.99          63
# 1.49          46
# 5.99          30
# 2.49          26
# 9.99          21
# 6.99          13
# 399.99        12
# 14.99         11
# 4.49           9
# 29.99          7
# 24.99          7
# 3.49           7
# 7.99           7
# 5.49           6
# 19.99          6
# 11.99          5
# 6.49           5
# 12.99          5
# 8.99           5
# 10.00          3
# 16.99          3
# 1.00           3
# 2.00           3
# 13.99          2
# 8.49           2
# 17.99          2
# 1.70           2
# 3.95           2
# 79.99          2
# 7.49           2
# 9.00           2
# 10.99          2
# 39.99          2
# 33.99          2
# 1.96           1
# 19.40          1
# 4.80           1
# 3.28           1
# 4.59           1
# 15.46          1
# 3.04           1
# 4.29           1
# 2.60           1
# 2.59           1
# 3.90           1
# 154.99         1
# 4.60           1
# ...

# %%
#change datatype to int of Price Column
df['Price'] = df['Price'].apply(lambda x: float(x))

# %%
df.describe()
# Out:
#             Rating       Reviews    Size_bytes      Installs         Price  \
# count  9367.000000  1.084100e+04  9.147000e+03  1.084100e+04  10841.000000
# mean      4.191513  4.441119e+05  2.255700e+07  1.546291e+07      1.027273
# std       0.515735  2.927629e+06  2.368560e+07  8.502557e+07     15.948971
# min       1.000000  0.000000e+00  8.704000e+03  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01  5.138022e+06  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03  1.363149e+07  1.000000e+05      0.000000
# 75%       4.500000  5.476800e+04  3.145728e+07  5.000000e+06      0.000000
# max       5.000000  7.815831e+07  1.048576e+08  1.000000e+09    400.000000
#
#            Size_Mb
# count  9147.000000
# mean     21.512029
# std      22.588347
# min       0.008301
# 25%       4.900000
# 50%      13.000000
# 75%      30.000000
# max     100.000000

# %%
# Using f String Print min, max and average prices of the app
print(f"Min price of the app is ${df.Price.min()}")
print(f"Max price of the app is ${df.Price.max()}")
print(f"Average price of the app is ${df.Price.mean()}")
# Out:
# Min price of the app is $0.0
# Max price of the app is $400.0
# Average price of the app is $1.0272733142699015

# %%
# missing values 
df.isnull().sum().sort_values(ascending=False )/len(df)*100
# Out:
# Size_bytes        15.625865
# Size_Mb           15.625865
# Rating            13.596532
# Current Ver        0.073794
# Android Ver        0.018448
# Category           0.009224
# Type               0.009224
# Genres             0.009224
# App                0.000000
# Reviews            0.000000
# Installs           0.000000
# Price              0.000000
# Content Rating     0.000000
# Last Updated       0.000000
# dtype: float64

# %%
# find total number of missing values
df.isnull().sum().sum()
# Out:
# 1487

# %%
#plot missing values
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %%
# Make figure size 16,6
plt.figure(figsize=(16,6))
# plot the null values bye their percentages in each column
missing_val_pecnt = df.isnull().sum()/len(df)*100
missing_val_pecnt.plot(kind='bar')

# sns.barplot(x=df.isnull().sum().sort_values(ascending=False)/len(df)*100, y=df.isnull().sum().sort_values(ascending=False).index)
# Out:
# <Axes: >

# %%
missing_val_pecnt[missing_val_pecnt < 1].plot(kind='bar')
# Out:
# <Axes: >
